# %%
def amortization(cost, duration, rate):
    return (rate * (1 + rate)**duration*cost) / ((1 + rate)**duration - 1)

print(amortization(1000, 60, 0.01))
# Out:
# 22.24444768490176

# %%
print(amortization(25000, 7*12, 0.07/12))
# Out:
# 377.31699955473374
